# %% [markdown]
# # M3 Data collection and management : project
# ## Planning my next holidays ☀️
#
# Let's put your dataset in a postgreSQL database on Amazon RDS ! Then, you can use the SQL syntax to make requests and decide where you'll go for your holidays 😎

# %%
# !pip3 install psycopg2-binary
# Out:
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun

# %% [markdown]
# 1. Read the .csv files containing information about cities and hotels

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
cities = pd.read_csv('res/1_destinations.csv')
hotels = pd.read_csv('res/3_hotels.csv')

# %%
cities.head()
# Out:
#    city_id                name   latitude  longitude main_weather  \
# 0       26           Collioure  42.525050   3.083155       Clouds
# 1       17  Bormes les Mimosas  43.150697   6.341929       Clouds
# 2       18              Cassis  43.214036   5.539632       Clouds
# 3       20     Aix en Provence  43.529842   5.447474         Rain
# 4       19           Marseille  43.296174   5.369953         Rain
#
#    expected_rain  day_temperature  rank  inverted_rank
# 0         0.1976         13.79500     1             34
# 1         4.0609         13.44500     2             33
# 2         4.1870         14.36625     3             32
# 3         4.8675         12.49000     4             31
# 4         5.7541         14.02125     5             30

# %%
hotels.head()
# Out:
#    city_id    city_name  hotel_id                                  name  \
# 0       33  La Rochelle         0  Lagrange Apart'Hotel l’Escale Marine
# 1       33  La Rochelle         1               Appart'City La Rochelle
# 2       33  La Rochelle         2           ibis La Rochelle Vieux Port
# 3       33  La Rochelle         3               ATHOME RESIDENCE ET SPA
# 4       33  La Rochelle         4        Best Western Premier Masqhotel
#
#                                                  url   latitude  longitude  \
# 0  https://www.booking.com/hotel/fr/l-escale-mari...  46.151070  -1.154863
# 1  https://www.booking.com/hotel/fr/appart-city-c...  46.158447  -1.141012
# 2  https://www.booking.com/hotel/fr/ibis-la-roche...  46.155829  -1.148558
# 3  https://www.booking.com/hotel/fr/athome-reside...  46.145995  -1.152398
# 4  https://www.booking.com/hotel/fr/masqhotel.fr....  46.154837  -1.145056
#
#    score                                        description
# 0    7.2  Le Lagrange Apart'Hotel l’Escale Marine vous a...
# 1    7.4  L’Appart'City La Rochelle se trouve à 10 minut...
# 2    8.3  Situé dans le quartier du Vieux-Port, dans le ...
# 3    8.0  Situé à La Rochelle, l'établissement ATHOME RE...
# 4    8.7  Le Best Western Masqhotel est un hôtel design ...

# %% [markdown]
# 2. Create and configure a RDS instance in your AWS account.
#
# 3. Use SQLAlchemy to create an engine that is connected to the remote database

# %%
engine = create_engine("postgresql+psycopg2://ENDPOINT/DB_NAME", echo=True)

# %% [markdown]
# 4. Create two tables in your remote database : `cities` and `hotels`, each one containing the information from the different .csv files you saved yesterday

# %%
cities.to_sql("cities", engine)
hotels.to_sql("hotels", engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# /opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: could not translate host name "ENDPOINT" to address: nodename nor servname provided, or not known
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-d607fc616b98> in <module>
# ----> 1 cities.to_sql("cities", engine)
#       2 hotels.to_sql("hotels", engine)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     719
#     720     def create(self):
# --> 721         if self.exists():
#     722             if self.if_exists == "fail":
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in exists(self)
#     706
#     707     def exists(self):
# --> 708         return self.pd_sql.has_table(self.name, self.schema)
#     709
#     710     def sql_schema(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    1428
#    1429     def has_table(self, name, schema=None):
# -> 1430         return self.connectable.run_callable(
#    1431             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1432         )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# /opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not translate host name "ENDPOINT" to address: nodename nor servname provided, or not known
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# 5. Optional : use PGAdmin to explore the database
#
# 6. Use SQL syntax to make a request that will help you get the list of the 30 best places to go (among all cities and hotels) 😎

# %%
conn = engine.connect()

statement = "SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url \
             FROM cities \
             INNER JOIN hotels \
             ON cities.city_id = hotels.city_id \
             WHERE rank <= 25 AND score IS NOT NULL \
             ORDER BY score DESC \
             LIMIT 30"

best_places = pd.read_sql(statement, conn)
# Out:
# 2020-09-21 12:55:23,003 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-09-21 12:55:23,004 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url              FROM cities              INNER JOIN hotels              ON cities.city_id = hotels.city_id              WHERE rank <= 25 AND score IS NOT NULL              ORDER BY score DESC              LIMIT 30'}
# 2020-09-21 12:55:23,170 INFO sqlalchemy.engine.base.Engine SELECT city_name, main_weather, day_temperature, hotels.name, description, score, url              FROM cities              INNER JOIN hotels              ON cities.city_id = hotels.city_id              WHERE rank <= 25 AND score IS NOT NULL              ORDER BY score DESC              LIMIT 30
# 2020-09-21 12:55:23,171 INFO sqlalchemy.engine.base.Engine {}

# %%
display(best_places)
# Out:
#    city_name main_weather  day_temperature  \
# 0     Bayeux         Rain         18.98125
# 1     Bayeux         Rain         18.98125
# 2     Bayeux         Rain         18.98125
# 3     Bayeux         Rain         18.98125
# 4     Bayeux         Rain         18.98125
# 5     Bayeux         Rain         18.98125
# 6     Bayeux         Rain         18.98125
# 7     Bayeux         Rain         18.98125
# 8     Bayeux         Rain         18.98125
# 9     Bayeux         Rain         18.98125
# 10    Bayeux         Rain         18.98125
# 11    Bayeux         Rain         18.98125
# 12    Bayeux         Rain         18.98125
# 13    Bayeux         Rain         18.98125
# 14    Bayeux         Rain         18.98125
# 15    Bayeux         Rain         18.98125
# 16    Bayeux         Rain         18.98125
# 17    Bayeux         Rain         18.98125
# 18    Bayeux         Rain         18.98125
# 19    Bayeux         Rain         18.98125
# 20    Bayeux         Rain         18.98125
# 21    Bayeux         Rain         18.98125
# 22    Bayeux         Rain         18.98125
# 23    Bayeux         Rain         18.98125
# 24    Bayeux         Rain         18.98125
# 25    Bayeux         Rain         18.98125
# 26    Bayeux         Rain         18.98125
# 27    Bayeux         Rain         18.98125
# 28    Bayeux         Rain         18.98125
# 29    Bayeux         Rain         18.98125
#
#                                                  name  \
# 0                                Ferme De La Fontaine
# 1                          Les Lilas de Bellefontaine
# 2                                      La Tour Bayeux
# 3                                  Le Chat Qui Veille
# 4                                         Gite Gerard
# 5                                      Le 32Bis suite
# 6             Hôtel particulier "le clos de la croix"
# 7                                          Le Boudoir
# 8                                         La Citadine
# 9                                    Villa Lara Hotel
# 10                             Manoir Sainte Victoire
# 11                               Château Saint Gilles
# 12                                 Appartement Bayeux
# 13  Sous les toits de Bayeux - Studio déco & zen -...
# 14                          Clos de Bellefontaine B&B
# 15                                     Le Grand Arbre
# 16                       Tiny house au cœur de Bayeux
# 17                                          Le 32 Bis
# 18                             Château de la Ferrière
# 19                                 LOGIS DU GRAND PIN
# 20                                     Le Petit Matin
# 21                           Loft du jardin botanique
# 22                                         La Colline
# 23                 Apartment Centre Historique Bayeux
# 24                                La Paresse en Ville
# 25                                     La Tour Louise
# 26                                       Normandyours
# 27                  Hotel Particulier de Sainte Croix
# 28                       Au cœur du centre historique
# 29   Nouveau, Charmant appartement au coeur de Bayeux
#
#                                           description  score  \
# 0   Offrant une vue sur le jardin, la Ferme De La ...    9.9
# 1   Situé à 600 mètres du musée de la Tapisserie d...    9.9
# 2   L'établissement La Tour Bayeux propose un hébe...    9.9
# 3   Situé à 1 km de la cathédrale Notre-Dame de Ba...    9.9
# 4   Situé à Bayeux, à seulement 200 mètres du cent...    9.8
# 5   Offrant une vue sur la ville, l'établissement ...    9.8
# 6   Offrant une vue sur le jardin, l'Hôtel particu...    9.8
# 7   Offrant une vue sur le jardin, Le Boudoir prop...    9.8
# 8   L'établissement La Citadine est un hébergement...    9.8
# 9   La Villa Lara Hotel est un petit boutique hôte...    9.7
# 10  Doté d'un jardin et d'une connexion Wi-Fi grat...    9.7
# 11  Situé à Bayeux, à 4 km du musée Baron Gérard, ...    9.7
# 12  Situé à Bayeux, à seulement 500 mètres du musé...    9.7
# 13  L'établissement Sous les toits de Bayeux - Stu...    9.7
# 14  Le Clos de Bellefontaine occupe une maison du ...    9.7
# 15  Situé à Bayeux, en Basse-Normandie, à 800 mètr...    9.7
# 16  Offrant une vue sur le jardin, le Tiny house a...    9.7
# 17  Doté d'une terrasse, l'établissement Le 32 Bis...    9.6
# 18  Situé à 10 km de la plage d'Arromanches, le Ch...    9.6
# 19  Offrant une vue sur le jardin, le LOGIS DU GRA...    9.6
# 20  Cette maison d'hôtes occupe un bâtiment du XVI...    9.6
# 21  Doté d'une terrasse, le Loft du jardin botaniq...    9.6
# 22  La Colline est située dans le centre-ville de ...    9.6
# 23  Doté d'une connexion Wi-Fi gratuite, l'Apartme...    9.6
# 24  Doté d'un court de tennis, l'établissement La ...    9.6
# 25  Entièrement rénové en 2015, l'établissement La...    9.6
# 26  Situé à Bayeux, à 500 mètres de la cathédrale ...    9.6
# 27  Doté d'un jardin, l'Hotel Particulier de Saint...    9.6
# 28  Doté d'une connexion Wi-Fi gratuite et offrant...    9.5
# 29  Offrant une vue sur la ville, le Nouveau, Char...    9.5
#
#                                                   url
# 0   https://www.booking.com/hotel/fr/ferme-de-la-f...
# 1   https://www.booking.com/hotel/fr/les-lilas-de-...
# 2   https://www.booking.com/hotel/fr/la-tour-bayeu...
# 3   https://www.booking.com/hotel/fr/gite-6-47-9-p...
# 4   https://www.booking.com/hotel/fr/city-break.fr...
# 5   https://www.booking.com/hotel/fr/le-32bis-suit...
# 6   https://www.booking.com/hotel/fr/particulier-q...
# 7   https://www.booking.com/hotel/fr/villa-bayeux....
# 8   https://www.booking.com/hotel/fr/la-citadine.f...
# 9   https://www.booking.com/hotel/fr/villa-lara-ha...
# 10  https://www.booking.com/hotel/fr/manoir-sainte...
# 11  https://www.booking.com/hotel/fr/chateau-saint...
# 12  https://www.booking.com/hotel/fr/appartement-b...
# 13  https://www.booking.com/hotel/fr/sous-les-toit...
# 14  https://www.booking.com/hotel/fr/chambres-d-ha...
# 15  https://www.booking.com/hotel/fr/le-grand-arbr...
# 16  https://www.booking.com/hotel/fr/tiny-house-au...
# 17  https://www.booking.com/hotel/fr/le-cocon-baye...
# 18  https://www.booking.com/hotel/fr/chateau-de-la...
# 19  https://www.booking.com/hotel/fr/logis-du-gran...
# 20  https://www.booking.com/hotel/fr/le-petit-mati...
# 21  https://www.booking.com/hotel/fr/loft-du-jardi...
# 22  https://www.booking.com/hotel/fr/la-colline-ba...
# 23  https://www.booking.com/hotel/fr/apartment-cen...
# 24  https://www.booking.com/hotel/fr/la-paresse-en...
# 25  https://www.booking.com/hotel/fr/le-relais-de-...
# 26  https://www.booking.com/hotel/fr/normandyours....
# 27  https://www.booking.com/hotel/fr/de-sainte-cro...
# 28  https://www.booking.com/hotel/fr/au-coeur-du-c...
# 29  https://www.booking.com/hotel/fr/nouveau-charm...
